# %%
import pandas as pd

# %%
texture = pd.read_csv('texture.csv')
texture = texture.drop(['Unnamed: 0'],axis=1)

# %%
texture
# Out:
#      texture                                           filename     empresa  \
# 0      673.0  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 1      596.9  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 2      275.1  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 3      722.2  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 4      923.6  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 5      793.4  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 6      790.9  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 7      273.9  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 8      156.0  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 9      876.9  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# 10     697.6  C:\Documents and Settings\Pine\Desktop\Lara\gr...  britacet 3
# ...
